# %%
using Pkg
Pkg.add(PackageSpec(url="https://github.com/SnowflurrySDK/Snowflurry.jl", rev="main"))
# Out:
#     Updating git-repo `https://github.com/SnowflurrySDK/Snowflurry.jl`
#    Resolving package versions...
#   No Changes to `C:\Users\bouch\.julia\environments\v1.10\Project.toml`
#   No Changes to `C:\Users\bouch\.julia\environments\v1.10\Manifest.toml`
# Precompiling project...
#   ✓ LaTeXStrings
#   ✓ UnPack
#   ✓ Contour
#   ✓ OrderedCollections
#   ✓ SimpleBufferStream
#   ✓ Observables
#   ✓ OffsetArrays
#   ✓ ExceptionUnwrapping
#   ✓ Grisu
#   ✓ Ratios
#   ✓ TranscodingStreams
#   ✓ Hiccup
#   ✓ Format
#   ✓ DelimitedFiles
#   ✓ Adapt
#   ✓ ChainRulesCore
#   ✓ LoggingExtras
#   ✓ FunctionalCollections
#   ✓ JLLWrappers
#   ✓ WoodburyMatrices
#   ✓ Lazy
#   ✓ AssetRegistry
#   ✓ Parameters
#   ✓ Tables
#   ✓ Ratios → RatiosFixedPointNumbersExt
#   ✗ BinaryProvider
#   ✓ DataStructures
#   ✓ Widgets
#   ✓ CodecZlib
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ OpenSSL_jll
#   ✓ Kaleido_jll
#   ✓ Graphite2_jll
# ...

# %%
using Snowflurry

# %%
c_phasehift = QuantumCircuit(qubit_count = 1, bit_count = 1)

push!(c_phasehift, x_90(1))
push!(c_phasehift, phase_shift(1, 5*pi/4))
push!(c_phasehift, x_minus_90(1))
print(c_phasehift)
# Out:
# Quantum Circuit Object:
#    qubit_count: 1
#    bit_count: 1
# q[1]:──X_90────P(3.9270)────X_m90──

# %%
user = "boucherf"
token = "jtl00AlxQsmOPaJsKYJP2+AF8E27rzS0"
host = "https://manager.anyonlabs.com"
project = ""
realm = "calculqc"

qpu = AnyonYamaskaQPU(host = host, user = user, access_token = token, project_id = project, realm = realm)
print(qpu)
# Out:
# Quantum Processing Unit:
#    manufacturer:  Anyon Systems Inc.
#    generation:    Yamaska
#    serial_number: ANYK202301
#    project_id:
#    qubit_count:   24
#    connectivity_type:  2D-lattice
#    realm:         calculqc

# %%
shot_count = 1000
push!(c_phasehift, readout(1, 1))
result = run_job(qpu, c, shot_count)
println(result)
# Out:
# (Dict("1" => 45, "0" => 955), 2186)

# %%
c_no_phaseshift = QuantumCircuit(qubit_count = 1, bit_count = 1)

push!(c_no_phaseshift, x_90(1))
push!(c_no_phaseshift, pi_8(1))
push!(c_no_phaseshift, sigma_z(1))
push!(c_no_phaseshift, x_minus_90(1))
print(c_no_phaseshift)
# Out:
# Quantum Circuit Object:
#    qubit_count: 1
#    bit_count: 1
# q[1]:──X_90────T────Z────X_m90──

# %%
shot_count = 1000
push!(c_no_phaseshift, readout(1, 1))
result = run_job(qpu, c_no_phaseshift, shot_count)
println(result)
# Out:
# (Dict("1" => 733, "0" => 267), 2232)
